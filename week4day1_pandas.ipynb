# %%
# Pandas

# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
#1D data structures in pandas

# %%
#pandas series

# %%
import pandas as pd

# %%
s = pd.Series([10,20,30])

# %%
s
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
s2 = pd.Series([9,74,87])

# %%
s2
# Out:
# 0     9
# 1    74
# 2    87
# dtype: int64

# %%
# costom index

# %%
s = pd.Series([10,20,30],index =['a','b','c'])

# %%
s
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
series = pd.Series(['sanskruti',18,85],index=['name','age','marks'])

# %%
series
# Out:
# name     sanskruti
# age             18
# marks           85
# dtype: object

# %%
# From Dictionary

# %%
data = {'name':"Rahul",'age':25,'marks':90}

# %%
data
# Out:
# {'name': 'Rahul', 'age': 25, 'marks': 90}

# %%
s = pd.Series(data)

# %%
s
# Out:
# name     Rahul
# age         25
# marks       90
# dtype: object

# %%
# from single value

# %%
s = pd.Series(5,index=[0,1,2,3])

# %%
s
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# dtype: int64

# %%
s = pd.Series('sanskruti',index=['a','b','c','d','e'])

# %%
s
# Out:
# a    sanskruti
# b    sanskruti
# c    sanskruti
# d    sanskruti
# e    sanskruti
# dtype: object

# %%
# Attributes

# %%
s = pd.Series([10,20,30],index=['a','b','c'])

# %%
s.values
# Out:
# array([10, 20, 30])

# %%
s.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
s.dtype
# Out:
# dtype('int64')

# %%
s.shape
# Out:
# (3,)

# %%
s.size
# Out:
# 3

# %%
# Data Manipulation

# %%
s = pd.Series([1,2,3])

# %%
print(s*3)
# Out:
# 0    3
# 1    6
# 2    9
# dtype: int64

# %%
# Handling missing values

# %%
s = pd.Series([1,None,3])

# %%
s
# Out:
# 0    1.0
# 1    NaN
# 2    3.0
# dtype: float64

# %%
s.isnull()
# Out:
# 0    False
# 1     True
# 2    False
# dtype: bool

# %%
s.dropna()
# Out:
# 0    1.0
# 2    3.0
# dtype: float64

# %%
s.fillna(0)
# Out:
# 0    1.0
# 1    0.0
# 2    3.0
# dtype: float64

# %%
# Indexing

# %%
s1 = pd.Series([10,20,30],index=['a','b','c'])

# %%
s1
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
s1['a']
# Out:
# np.int64(10)

# %%
s1['c']
# Out:
# np.int64(30)
